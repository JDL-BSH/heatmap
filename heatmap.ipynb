# %%
# Out:
# Requirement already satisfied: seaborn in c:\users\laj1mu\appdata\local\anaconda3\lib\site-packages (0.12.2)
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\laj1mu\appdata\local\anaconda3\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\laj1mu\appdata\local\anaconda3\lib\site-packages (from seaborn) (2.1.4)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\laj1mu\appdata\local\anaconda3\lib\site-packages (from seaborn) (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\laj1mu\appdata\local\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\laj1mu\appdata\local\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\laj1mu\appdata\local\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\laj1mu\appdata\local\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\laj1mu\appdata\local\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\laj1mu\appdata\local\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\laj1mu\appdata\local\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\laj1mu\appdata\local\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\laj1mu\appdata\local\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\laj1mu\appdata\local\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\laj1mu\appdata\local\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    ---- ---------------------------------- 30.7/294.9 kB 660.6 kB/s eta 0:00:01
#    --------- ----------------------------- 71.7/294.9 kB 991.0 kB/s eta 0:00:01
#    -------------------------------------- - 286.7/294.9 kB 2.2 MB/s eta 0:00:01
#    ---------------------------------------- 294.9/294.9 kB 2.0 MB/s eta 0:00:00
# Installing collected packages: seaborn
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.12.2
#     Uninstalling seaborn-0.12.2:
#       Successfully uninstalled seaborn-0.12.2
# Successfully installed seaborn-0.13.2

# %%
#Heatmap for Threat Landscape and Security Posture
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Example data
data = {
    "Technique": ["T1059", "T1047", "T1003", "T1078", "T1071"],
    "Threat Frequency": [3, 2, 4, 1, 3],  # 1: Low, 2: Medium, 3: High, 4: Very High
    "Threat Impact": [4, 3, 4, 2, 3],     # 1: Low, 2: Medium, 3: High, 4: Critical
    "Detection Coverage": [1, 2, 3, 4, 2],# 1: Poor, 2: Fair, 3: Good, 4: Excellent
    "Response Effectiveness": [2, 3, 1, 4, 3], # 1: Poor, 2: Fair, 3: Good, 4: Excellent
    "Residual Risk": [3, 3, 4, 2, 3]      # 1: Low, 2: Medium, 3: High, 4: Very High
}

# Convert to DataFrame
df = pd.DataFrame(data)

# Set the index to the technique for better visualization
df.set_index("Technique", inplace=True)
print (df)

# Create the heatmap
plt.figure(figsize=(12, 6))
#sns.heatmap(df, annot=True, cmap="YlGnBu", cbar_kws={'label': 'Risk Level'})
colormap = sns.color_palette("coolwarm")
sns.heatmap(df, cmap=colormap, annot=True, linewidth=.5)
plt.title('Threat Landscape and Security Posture Heatmap')
plt.show()
# Out:
#            Threat Frequency  Threat Impact  Detection Coverage  \
# Technique
# T1059                     3              4                   1
# T1047                     2              3                   2
# T1003                     4              4                   3
# T1078                     1              2                   4
# T1071                     3              3                   2
#
#            Response Effectiveness  Residual Risk
# Technique
# T1059                           2              3
# T1047                           3              3
# T1003                           1              4
# T1078                           4              2
# T1071                           3              3
